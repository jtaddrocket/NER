# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import copy
import json
import logging
import torch
from datasets import Dataset
import wandb
wandb.login(key="3c7f2cf75c1da878f1d39d575642a30466893b47")
from transformers import (
    AutoTokenizer, 
    T5ForTokenClassification, 
    TrainingArguments, 
    Trainer,
    DataCollatorForTokenClassification
)
from sklearn.metrics import classification_report
import numpy as np
from transformers import EvalPrediction

def read_conll(file_path):
    sentences = []
    sentence_labels = []
    unique_labels = set()

    with open(file_path, 'r', encoding='utf-8') as file:
        current_sentence_tokens = []
        current_sentence_labels = []

        for line in file:
            line = line.strip()
            if not line:
                if current_sentence_tokens:
                    sentences.append(' '.join(current_sentence_tokens))
                    sentence_labels.append(' '.join(current_sentence_labels))
                current_sentence_tokens = []
                current_sentence_labels = []
            else:
                line_parts = line.split()
                current_sentence_tokens.append(line_parts[0])
                if len(line_parts) >= 4:
                    current_sentence_labels.append(line_parts[3])
                    unique_labels.add(line_parts[3])
                else:
                    current_sentence_labels.append('O')

    if current_sentence_tokens:
        sentences.append(' '.join(current_sentence_tokens))
        sentence_labels.append(' '.join(current_sentence_labels))

    return sentences, sentence_labels

def read_conll_directory(directory_path):
    all_sentences = []
    all_sentence_labels = []

    for file_name in os.listdir(directory_path):
        if file_name.endswith('.conll'):
            file_path = os.path.join(directory_path, file_name)
            print(f"Processing file: {file_path}")
            sentences, sentence_labels = read_conll(file_path)
            all_sentences.extend(sentences)
            all_sentence_labels.extend(sentence_labels)

    return all_sentences, all_sentence_labels

def extract_labels(label_sentences):
    unique_labels = set()
    for sentence in label_sentences:
        labels = sentence.split()
        unique_labels.update(labels)
    return unique_labels

# Load data
train_directory = '/kaggle/input/vlsp2021-fixed/Train-Conll'  # Replace with your path
dev_directory = '/kaggle/input/vlsp2021-fixed/Dev-Conll'      # Replace with your path

train_sentences, train_labels = read_conll_directory(train_directory)
dev_sentences, dev_labels = read_conll_directory(dev_directory)

# Get unique labels and create label mapping
train_unique_labels = extract_labels(train_labels)
dev_unique_labels = extract_labels(dev_labels)
label_list = sorted(train_unique_labels.union(dev_unique_labels))
label2id = {label: i for i, label in enumerate(label_list)}
id2label = {i: label for label, i in label2id.items()}

print(f"Number of labels: {len(label_list)}")
print(f"Train size: {len(train_sentences)}")
print(f"Dev size: {len(dev_sentences)}")

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("VietAI/vit5-base")
model = T5ForTokenClassification.from_pretrained(
    "VietAI/vit5-base",
    num_labels=len(label_list),
    id2label=id2label,
    label2id=label2id
)
for param in model.parameters(): param.data = param.data.contiguous()

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"],
        padding=True,
        truncation=True,
        max_length=256,
        return_tensors="pt"
    )

    labels = []
    for i, label in enumerate(examples["labels"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label2id[label[word_idx]])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# Prepare datasets
train_dataset = Dataset.from_dict({
    "text": train_sentences,
    "labels": [label.split() for label in train_labels]
})

dev_dataset = Dataset.from_dict({
    "text": dev_sentences,
    "labels": [label.split() for label in dev_labels]
})

# Tokenize datasets
tokenized_train = train_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=train_dataset.column_names
)

tokenized_dev = dev_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=dev_dataset.column_names
)

# def compute_metrics(eval_preds):
#     predictions, labels = eval_preds
#     predictions = np.argmax(predictions, axis=2)

#     # Map predictions and labels to their string values (ignore padding tokens)
#     true_predictions = [
#         [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
#         for prediction, label in zip(predictions, labels)
#     ]
#     true_labels = [
#         [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
#         for prediction, label in zip(predictions, labels)
#     ]

#     # Flatten the true and predicted labels for the classification report
#     true_labels_flat = [label for sublist in true_labels for label in sublist]
#     pred_labels_flat = [label for sublist in true_predictions for label in sublist]

#     # Generate classification report
#     report = classification_report(
#         true_labels_flat,
#         pred_labels_flat,
#         labels=label_list,
#         zero_division=0,
#         output_dict=True
#     )

#     # Print detailed classification report for per-class metrics
#     print("\nDetailed Classification Report:")
#     print(classification_report(
#         true_labels_flat,
#         pred_labels_flat,
#         labels=label_list,
#         zero_division=0
#     ))

#     # Extract micro-averaged metrics
#     precision = report["micro avg"]["precision"]
#     recall = report["micro avg"]["recall"]
#     f1 = report["micro avg"]["f1-score"]

#     # Return results as a dictionary
#     return {
#         "precision": precision,
#         "recall": recall,
#         "f1": f1,
#     }



from sklearn.metrics import classification_report

def compute_metrics(p: EvalPrediction):
    predictions = p.predictions.argmax(axis=2)  # Convert logits to class predictions
    labels = p.label_ids

    pred_labels_flat = []
    true_labels_flat = []

    correct = 0  # For accuracy calculation
    total = 0    # For accuracy calculation

    # Flatten predictions and labels while ignoring padding tokens (-100)
    for pred_seq, true_seq in zip(predictions, labels):
        for pred_id, true_id in zip(pred_seq, true_seq):
            if true_id == -100:  # Skip padding tokens
                continue
            pred_labels_flat.append(label_list[pred_id])
            true_labels_flat.append(label_list[true_id])

            # Update accuracy counts
            total += 1
            if pred_id == true_id:
                correct += 1

    # Filter out the 'O' (non-entity) label from metrics
    entity_labels = [label for label in label_list if label != 'O']

    # Print detailed classification report for debugging
    print("\nDetailed Classification Report:")
    print(classification_report(
        true_labels_flat,
        pred_labels_flat,
        labels=entity_labels,
        digits=4,
        zero_division=0
    ))

    # Generate report to extract metrics
    report = classification_report(
        true_labels_flat,
        pred_labels_flat,
        labels=entity_labels,
        zero_division=0,
        output_dict=True
    )

    # Extract micro-averaged metrics
    precision = report["micro avg"]["precision"]
    recall = report["micro avg"]["recall"]
    f1 = report["micro avg"]["f1-score"]

    # Calculate accuracy
    accuracy = correct / total if total > 0 else 0.0

    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "accuracy": accuracy,
    }




# Training arguments
training_args = TrainingArguments(
    output_dir="./t5-token-classification",
    evaluation_strategy="epoch",
    per_device_train_batch_size=48,
    per_device_eval_batch_size=48,
    num_train_epochs=4,
    weight_decay=0.01,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=100,
    save_steps=500,
    fp16=True,
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized
conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_thethao_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_giaoduc_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thegioi_0024.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_doisong_0003.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_kinhte_kinhdoanh_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thegioi_0022.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_xahoi_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_doisong_0011.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_phapluat_0003.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_giaitri_amnhac_0009.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_vanhoa_0028.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_vanhoa_0005.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_congnghe_vienthong_0007.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_khcn_0024.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_doisong_0005.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_congnghe_0007.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_phapluat_0005.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_congnghe_thietbi_phancung_0005.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_xahoi_0029.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_thethao_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_giaitri_amnhac_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_giaoduc_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_vanhoa_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_xahoi_moitruong_khihau_0001.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_doisong_0014.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_congnghe_0006.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_kinhte_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_xahoi_0027.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_kinhte_chungkhoan_0003.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thethao_0019.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thethao_0023.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_vanhoa_0003.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_giaoduc_0006.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_xahoi_thoisu_0013.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_thethao_bongda_0010.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_xahoi_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_thethao_bongda_0001.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_xahoi_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_giaitri_0017.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_giaoduc_0020.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thegioi_0006.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/1_test_vanhoa_dulich_0002.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thethao_0017.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_thethao_0008.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_giaitri_0024.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_vanhoa_0004.conll
# Processing file: /kaggle/input/vlsp2021-fixed/Dev-Conll/0_dev_doisong_0013.conll
# Number of labels: 83
# Train size: 12887
# Dev size: 6806
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of T5ForTokenClassification were not initialized from the model checkpoint at VietAI/vit5-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map:   0%|          | 0/12887 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6806 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='136' max='540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [136/540 04:45 < 14:21, 0.47 it/s, Epoch 1/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='71' max='71' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [71/71 00:57]
#     </div>
# Detailed Classification Report:
#                        precision    recall  f1-score   support
#
#             B-ADDRESS     0.0000    0.0000    0.0000         4
#            B-DATETIME     0.5648    0.5535    0.5591      1158
#       B-DATETIME-DATE     0.4806    0.2727    0.3480       363
#  B-DATETIME-DATERANGE     0.0000    0.0000    0.0000       111
#   B-DATETIME-DURATION     0.6716    0.6193    0.6444       436
#        B-DATETIME-SET     0.0000    0.0000    0.0000        16
#       B-DATETIME-TIME     0.0882    0.1622    0.1143        37
#  B-DATETIME-TIMERANGE     0.1765    0.0375    0.0619        80
#               B-EMAIL     0.0000    0.0000    0.0000         1
#               B-EVENT     0.1509    0.0734    0.0988       109
#           B-EVENT-CUL     0.0000    0.0000    0.0000        58
#      B-EVENT-GAMESHOW     0.1304    0.1250    0.1277        48
#       B-EVENT-NATURAL     0.0000    0.0000    0.0000        17
#         B-EVENT-SPORT     0.1528    0.5116    0.2353        43
#                  B-IP     0.0000    0.0000    0.0000         0
#            B-LOCATION     0.4167    0.3233    0.3641      1856
#        B-LOCATION-GEO     0.3269    0.2048    0.2519        83
#        B-LOCATION-GPE     0.4487    0.6982    0.5463      1554
#      B-LOCATION-STRUC     0.1930    0.1028    0.1341       107
#       B-MISCELLANEOUS     0.2360    0.1235    0.1622       170
#        B-ORGANIZATION     0.6709    0.6266    0.6480      3227
#       I-PRODUCT-LEGAL     0.1500    0.1849    0.1656       146
#            I-QUANTITY     0.4947    0.1845    0.2688      1512
#        I-QUANTITY-AGE     0.8599    0.8133    0.8359       166
#        I-QUANTITY-CUR     0.8391    0.4949    0.6226       685
#        I-QUANTITY-DIM     0.4933    0.3162    0.3854       117
#        I-QUANTITY-NUM     0.3095    0.3333    0.3210        39
#        I-QUANTITY-ORD     0.2955    0.4407    0.3537        59
#        I-QUANTITY-PER     0.9114    0.7097    0.7980       565
#        I-QUANTITY-TEM     0.1429    0.3750    0.2069        16
#               I-SKILL     0.0000    0.0000    0.0000         0
#                 I-URL     0.9412    0.7619    0.8421        21
#
#             micro avg     0.5750    0.5462    0.5602     48625
#             macro avg     0.3111    0.2877    0.2745     48625
#          weighted avg     0.5881    0.5462    0.5479     48625
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d3f752b9af12> in <cell line: 283>()
#     281
#     282 # Train the model
# --> 283 trainer.train()
#     284
#     285 # Save the model
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1936                 hf_hub_utils.enable_progress_bars()
#    1937         else:
# -> 1938             return inner_training_loop(
#    1939                 args=args,
#    1940                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2374
#    2375             self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2376             self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2377
#    2378             if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2802         metrics = None
#    2803         if self.control.should_evaluate:
# -> 2804             metrics = self._evaluate(trial, ignore_keys_for_eval)
#    2805
#    2806         if self.control.should_save:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    2759
#    2760     def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 2761         metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2762         self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2763
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3664
#    3665         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3666         output = eval_loop(
#    3667             eval_dataloader,
#    3668             description="Evaluation",
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3954                 )
#    3955             else:
# -> 3956                 metrics = self.compute_metrics(EvalPrediction(predictions=all_preds, label_ids=all_labels))
#    3957         elif metrics is None:
#    3958             metrics = {}
#
# <ipython-input-4-d3f752b9af12> in compute_metrics(p)
#     243     recall = report["micro avg"]["recall"]
#     244     f1 = report["micro avg"]["f1-score"]
# --> 245     accuracy = report["accuracy"]  # Accuracy is directly available in the report
#     246
#     247     return {
#
# KeyError: 'accuracy'

# %%
def predict_ner(text, model, tokenizer, max_length=256):
    # Prepare input
    inputs = tokenizer(
        text,
        max_length=max_length,
        padding="max_length",
        truncation=True,
        return_tensors="pt"
    )
    
    # Move to GPU if available
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    
    # Get predictions
    with torch.no_grad():
        outputs = model(**inputs)
        predictions = outputs.logits.argmax(dim=-1)
    
    # Convert predictions to labels
    input_tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])
    raw_predictions = [(token, label_list[pred.item()]) 
                      for token, pred in zip(input_tokens, predictions[0])
                      if token not in [tokenizer.pad_token, tokenizer.eos_token, tokenizer.bos_token]]
    
    # Clean up predictions
    cleaned_predictions = []
    i = 0
    while i < len(raw_predictions):
        token, label = raw_predictions[i]
        
        if token.startswith('▁') and (label.startswith('B-') or label.startswith('I-')):
            # Start of a new word
            full_token = token.replace('▁', '')
            full_label = label
            
            # Look ahead for continuation of the same entity
            j = i + 1
            while j < len(raw_predictions) and not raw_predictions[j][0].startswith('▁'):
                full_token += raw_predictions[j][0]
                j += 1
            i = j - 1
            
            cleaned_predictions.append((full_token, full_label))
        elif not token.startswith('▁') and label != 'O':
            # Handle non-word-initial subwords
            continue
        else:
            # Handle other tokens
            if label != 'O':
                cleaned_predictions.append((token.replace('▁', ''), label))
        i += 1
    
    return cleaned_predictions



# Test the model with sample text
test_text = """Sofascore là hãng thống kê hàng đầu thế giới, do người Croatia sáng lập năm 2010 
và có hàng chục triệu người dùng. Theo mô hình của hãng, Xuân Son nhận điểm 10 và 
dĩ nhiên là cầu thủ hay nhất trận. Vĩ Hào đứng thứ hai với 8,4 điểm, nhờ một bàn 
và một đường kiến tạo, còn Nguyễn Quang Hải nhận 8,2 điểm với một bàn."""

# Get predictions
predictions = predict_ner(test_text, model, tokenizer)

# Print results in a readable format
print("\nNER Predictions:")
print("-" * 50)
for token, label in predictions:
    if label != "O":
        print(f"Token: {token:} Label: {label}")
# Out:
# NER Predictions:
# --------------------------------------------------
# Token: Sofascore Label: B-PERSON
# Token: người Label: B-MISCELLANEOUS
# Token: Croatia Label: B-LOCATION-GPE
# Token: năm Label: B-DATETIME
# Token: 2010 Label: I-DATETIME
# Token: triệu Label: I-QUANTITY-NUM
# Token: Xuân Label: B-PERSON
# Token: Son Label: I-PERSON
# Token: 10 Label: B-QUANTITY-NUM
# Token: Vĩ Label: B-PERSON
# Token: Hào Label: I-PERSON
# Token: hai Label: I-QUANTITY-ORD
# Token: 8,4 Label: B-QUANTITY-NUM
# Token: một Label: B-QUANTITY-NUM
# Token: Nguyễn Label: B-PERSON
# Token: Quang Label: I-PERSON
# Token: Hải Label: I-PERSON
# Token: 8,2 Label: B-QUANTITY-NUM

# %%
###################################
# 1. Read Test data and check labels
###################################
test_directory = '/kaggle/input/vlsp-2021-test'
test_sentences, test_labels = read_conll_directory(test_directory)

# Check for unknown labels
test_unique_labels = extract_labels(test_labels)
unknown_labels = test_unique_labels - set(label_list)
if unknown_labels:
    print(f"Warning: Found unknown labels in test set: {unknown_labels}")
    print("These will be mapped to 'O'")

###################################
# 2. Prepare Test Dataset
###################################
test_dataset = Dataset.from_dict({
    "text": test_sentences,
    "labels": [label.split() for label in test_labels]
})

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"],
        padding=True,
        truncation=True,
        max_length=256,
        return_tensors="pt"
    )

    labels = []
    for i, label in enumerate(examples["labels"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                # Handle unknown labels by mapping them to 'O'
                label_id = label2id.get(label[word_idx], label2id['O'])
                label_ids.append(label_id)
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# Tokenize test dataset
tokenized_test = test_dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=test_dataset.column_names
)

###################################
# 3. Evaluate on Test Set
###################################
test_trainer = Trainer(
    model=model,
    args=TrainingArguments(
        output_dir="./test-output",
        per_device_eval_batch_size=48,
        fp16=True,
    ),
    tokenizer=tokenizer,
    data_collator=DataCollatorForTokenClassification(tokenizer),
    compute_metrics=compute_metrics,
)

# Run prediction
print("Starting evaluation on test set...")
predictions = test_trainer.predict(tokenized_test)

# Process predictions
pred_labels = np.argmax(predictions.predictions, axis=2)

# Convert predictions to labels
true_predictions = [
    [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
    for prediction, label in zip(pred_labels, predictions.label_ids)
]

# Process predictions and ensure alignment
print("\nProcessing predictions...")
processed_true = []
processed_pred = []

for sentence, true_lab, pred_lab in zip(test_sentences, test_labels, true_predictions):
    true_tokens = true_lab.split()
    
    # Ensure predictions match the number of true labels
    if len(pred_lab) > len(true_tokens):
        pred_lab = pred_lab[:len(true_tokens)]
    elif len(pred_lab) < len(true_tokens):
        pred_lab = pred_lab + ['O'] * (len(true_tokens) - len(pred_lab))
    
    processed_true.extend(true_tokens)
    processed_pred.extend(pred_lab)

# Verify lengths match
assert len(processed_true) == len(processed_pred), \
    f"Mismatch in lengths: true={len(processed_true)}, pred={len(processed_pred)}"

# Print evaluation metrics
print("\nTest Set Evaluation:")
print("-" * 50)
print(classification_report(
    processed_true,
    processed_pred,
    labels=[l for l in label_list if l != 'O'],
    digits=4,
    zero_division=0
))

# Save detailed analysis with aligned predictions
with open('test_predictions_detailed.txt', 'w', encoding='utf-8') as f:
    for i, (sentence, true_lab, pred_lab) in enumerate(zip(test_sentences, test_labels, true_predictions)):
        true_tokens = true_lab.split()
        # Ensure predictions are aligned
        pred_aligned = pred_lab[:len(true_tokens)] if len(pred_lab) > len(true_tokens) else pred_lab + ['O'] * (len(true_tokens) - len(pred_lab))
        
        f.write(f"Example {i+1}:\n")
        f.write(f"Text: {sentence}\n")
        f.write(f"True: {true_lab}\n")
        f.write(f"Pred: {' '.join(pred_aligned)}\n")
        
        # Add token-level comparison
        f.write("\nToken-level comparison:\n")
        f.write("Token\tTrue\tPred\n")
        tokens = sentence.split()
        for token, true_label, pred_label in zip(tokens, true_tokens, pred_aligned):
            if true_label != pred_label:
                f.write(f"{token}\t{true_label}\t{pred_label}\n")
        f.write("-" * 50 + "\n\n")

# Save aligned predictions in CONLL format
with open('test_predictions.conll', 'w', encoding='utf-8') as f:
    for sentence, true_lab, pred_lab in zip(test_sentences, test_labels, true_predictions):
        tokens = sentence.split()
        true_tokens = true_lab.split()
        # Ensure predictions are aligned
        pred_aligned = pred_lab[:len(true_tokens)] if len(pred_lab) > len(true_tokens) else pred_lab + ['O'] * (len(true_tokens) - len(pred_lab))
        
        for token, pred in zip(tokens, pred_aligned):
            f.write(f"{token}\t_\t_\t{pred}\tO\n")
        f.write("\n")

print("\nPredictions have been saved to:")
print("1. test_predictions.conll - CONLL format")
print("2. test_predictions_detailed.txt - Detailed analysis")
# Out:
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_giaoduc_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_phapluat_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_batdongsan_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_giaitri_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_xahoi_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaoduc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_xahoi_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_suckhoe_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_xahoi_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_doisong_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thoisu_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_suckhoe_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_congnghe_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaitri_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_congnghe_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_kinhdoanh_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_doisong_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_giaoduc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thoisu_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_sukien_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_suckhoe_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_giaoduc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_kinhdoanh_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_xahoi_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaoduc_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_nhanai_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_truyenhinh_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_kinhdoanh_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_thethao_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_congnghe_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaoduc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_phapluat_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_congnghe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_xahoi_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_thegioi_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_dulich_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_giaoduc_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_congnghe_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_kinhdoanh_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_phapluat_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaoduc_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_phapluat_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_nhanai_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaitri_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_suckhoe_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thethao_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_dulich_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_suckhoe_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thoisu_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thethao_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_gocnhin_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_khoahoc_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_truyenhinh_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_vieclam_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_kinhdoanh_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_vanhoa_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_suckhoe_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaitri_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_congnghe_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_khoahoc_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thethao_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_suckhoe_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thethao_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_doisong_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_kinhdoanh_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_thethao_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_vanhoa_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_thegioi_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaoduc_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_thethao_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_giaoduc_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_thegioi_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_sukien_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_thoisu_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_phapluat_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_thethao_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_nhanai_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_thethao_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_sukien_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaitri_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaitri_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_truyenhinh_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_thegioi_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_doisong_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_kinhdoanh_0010.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_congnghe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_xahoi_0009.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_doisong_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_thethao_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_thethao_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaitri_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_thegioi_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_kinhdoanh_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_thethao_0010.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_suckhoe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_khoahoc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_truyenhinh_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_kinhdoanh_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_thethao_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_vanhoa_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_phapluat_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaoduc_0006.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaitri_0007.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_phapluat_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_congnghe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaoduc_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_batdongsan_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_phapluat_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_vanhoa_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_giaoduc_0008.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_phapluat_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_khoahoc_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_kinhte_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_congnghe_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_kinhdoanh_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_suckhoe_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_doisong_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_congnghe_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_doisong_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_suckhoe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_kinhte_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_giaoduc_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_zingnews_thegioi_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_thegioi_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vtv_truyenhinh_0010.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_xahoi_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/1_test_vnexpress_dulich_0003.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_giaitri_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_kinhdoanh_0001.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_suckhoe_0004.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_thethao_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi_doisong_0002.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_baomoi
0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/2_test_dantri_nhanai_0005.conll
# Processing file: /kaggle/input/vlsp-2021-test/0_test_vnexpress_phapluat_0003.conll
# Warning: Found unknown labels in test set: {'A', 'B'}
# These will be mapped to 'O'
# Map:   0%|          | 0/3990 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Starting evaluation on test set...
# Detailed Classification Report:
#                        precision    recall  f1-score   support
#
#             B-ADDRESS     0.5000    0.1304    0.2069        23
#            B-DATETIME     0.4919    0.6288    0.5520       625
#       B-DATETIME-DATE     0.6554    0.5663    0.6076       581
#  B-DATETIME-DATERANGE     0.3333    0.0211    0.0397       142
#   B-DATETIME-DURATION     0.8651    0.6953    0.7710       489
#        B-DATETIME-SET     0.0000    0.0000    0.0000         4
#       B-DATETIME-TIME     0.6618    0.8333    0.7377        54
#  B-DATETIME-TIMERANGE     0.7397    0.4091    0.5268       132
#               B-EMAIL     0.0000    0.0000    0.0000         2
#               B-EVENT     0.4918    0.1657    0.2479       181
#           B-EVENT-CUL     0.7500    0.3750    0.5000        16
#      B-EVENT-GAMESHOW     0.3509    0.3509    0.3509        57
#       B-EVENT-NATURAL     1.0000    0.2222    0.3636         9
#         B-EVENT-SPORT     0.5298    0.5817    0.5545       153
#                  B-IP     0.4000    0.5333    0.4571        15
#            B-LOCATION     0.0982    0.1745    0.1257       470
#        B-LOCATION-GEO     0.5400    0.2030    0.2951       133
#        B-LOCATION-GPE     0.7436    0.7002    0.7212      2498
#      B-LOCATION-STRUC     0.5048    0.3581    0.4190       148
#       B-MISCELLANEOUS     0.0000    0.0000    0.0000         0
#        B-ORGANIZATION     0.6814    0.7490    0.7136      1713
#    B-ORGANIZATION-MED     0.8333    0.2362    0.3681       127
# B-ORGANIZATION-SPORTS     0.5919    0.8519    0.6985       412
#  B-ORGANIZATION-STOCK     0.0000    0.0000    0.0000        37
#              B-PERSON     0.9020    0.9260    0.9138      2663
#          B-PERSONTYPE     0.7454    0.7886    0.7664       828
#         B-PHONENUMBER     0.5000    0.9000    0.6429        10
#             B-PRODUCT     0.3513    0.3937    0.3713       480
#       B-PRODUCT-AWARD     0.0000    0.0000    0.0000        81
#         B-PRODUCT-COM     0.4245    0.3642    0.3920       162
#       B-PRODUCT-LEGAL     0.9444    0.2012    0.3317       169
#            B-QUANTITY     0.0821    0.4258    0.1376       155
#        B-QUANTITY-AGE     0.8244    0.9020    0.8614       255
#        B-QUANTITY-CUR     0.8679    0.8301    0.8486       459
#        B-QUANTITY-DIM     0.7717    0.2700    0.4000       263
#        B-QUANTITY-NUM     0.7741    0.4775    0.5907      2224
#        B-QUANTITY-ORD     0.5705    0.1926    0.2880       462
#        B-QUANTITY-PER     0.9556    0.8777    0.9150       368
#        B-QUANTITY-TEM     0.0000    0.0000    0.0000        11
#               B-SKILL     0.0000    0.0000    0.0000         2
#                 B-URL     0.6250    0.6250    0.6250         8
#             I-ADDRESS     0.3958    0.1306    0.1964       291
#            I-DATETIME     0.5120    0.6420    0.5697       662
#       I-DATETIME-DATE     0.7121    0.5423    0.6157       520
#  I-DATETIME-DATERANGE     0.7365    0.2891    0.4152       377
#   I-DATETIME-DURATION     0.8310    0.6597    0.7355       529
#        I-DATETIME-SET     0.0000    0.0000    0.0000        20
#       I-DATETIME-TIME     0.6500    0.5417    0.5909        72
#  I-DATETIME-TIMERANGE     0.5000    0.0559    0.1005       179
#               I-EMAIL     1.0000    0.2500    0.4000         4
#               I-EVENT     0.5173    0.3375    0.4085       797
#           I-EVENT-CUL     0.4706    0.3077    0.3721        26
#      I-EVENT-GAMESHOW     0.2965    0.3252    0.3102       206
#       I-EVENT-NATURAL     0.0000    0.0000    0.0000        17
#         I-EVENT-SPORT     0.7850    0.5526    0.6486       456
#                  I-IP     0.0000    0.0000    0.0000         0
#            I-LOCATION     0.1274    0.2025    0.1564       721
#        I-LOCATION-GEO     0.5755    0.2877    0.3836       212
#        I-LOCATION-GPE     0.6648    0.7042    0.6839      2309
#      I-LOCATION-STRUC     0.5306    0.5130    0.5216       423
#       I-MISCELLANEOUS     0.0000    0.0000    0.0000         0
#        I-ORGANIZATION     0.7024    0.7047    0.7035      4206
#    I-ORGANIZATION-MED     0.7746    0.4056    0.5324       466
# I-ORGANIZATION-SPORTS     0.5692    0.7351    0.6416       302
#  I-ORGANIZATION-STOCK     0.0000    0.0000    0.0000        38
#              I-PERSON     0.8849    0.9620    0.9218      2366
#          I-PERSONTYPE     0.7006    0.5279    0.6021      2150
#         I-PHONENUMBER     0.4000    0.9091    0.5556        11
#             I-PRODUCT     0.4697    0.3240    0.3835      1148
#       I-PRODUCT-AWARD     0.0000    0.0000    0.0000       366
#         I-PRODUCT-COM     0.2776    0.3077    0.2918       221
#       I-PRODUCT-LEGAL     0.9357    0.1534    0.2636       854
#            I-QUANTITY     0.0739    0.3092    0.1193       207
#        I-QUANTITY-AGE     0.9612    0.8677    0.9121       257
#        I-QUANTITY-CUR     0.9175    0.8648    0.8904       836
#        I-QUANTITY-DIM     0.8750    0.3043    0.4516       184
#        I-QUANTITY-NUM     0.7051    0.5500    0.6180       100
#        I-QUANTITY-ORD     0.6015    0.3980    0.4790       201
#        I-QUANTITY-PER     0.9331    0.8187    0.8722       375
#        I-QUANTITY-TEM     0.7500    0.8750    0.8077        24
#               I-SKILL     0.0000    0.0000    0.0000         4
#                 I-URL     1.0000    1.0000    1.0000         4
#
#             micro avg     0.6472    0.6020    0.6238     38762
#             macro avg     0.5236    0.4185    0.4329     38762
#          weighted avg     0.6816    0.6020    0.6201     38762
#
#
# Processing predictions...
#
# Test Set Evaluation:
# --------------------------------------------------
#                        precision    recall  f1-score   support
#
#             B-ADDRESS     0.5000    0.1304    0.2069        23
#            B-DATETIME     0.4919    0.6288    0.5520       625
#       B-DATETIME-DATE     0.6554    0.5663    0.6076       581
#  B-DATETIME-DATERANGE     0.3333    0.0211    0.0397       142
#   B-DATETIME-DURATION     0.8651    0.6939    0.7701       490
#        B-DATETIME-SET     0.0000    0.0000    0.0000         4
#       B-DATETIME-TIME     0.6618    0.8333    0.7377        54
#  B-DATETIME-TIMERANGE     0.7397    0.4091    0.5268       132
#               B-EMAIL     0.0000    0.0000    0.0000         2
#               B-EVENT     0.4918    0.1648    0.2469       182
#       I-MISCELLANEOUS     0.0000    0.0000    0.0000         0
#        I-ORGANIZATION     0.7024    0.7022    0.7023      4221
#    I-ORGANIZATION-MED     0.7746    0.4056    0.5324       466
# I-ORGANIZATION-SPORTS     0.5692    0.7351    0.6416       302
#  I-ORGANIZATION-STOCK     0.0000    0.0000    0.0000        38
#              I-PERSON     0.8849    0.9620    0.9218      2366
#          I-PERSONTYPE     0.7006    0.5279    0.6021      2150
#         I-PHONENUMBER     0.4000    0.9091    0.5556        11
#             I-PRODUCT     0.4697    0.3240    0.3835      1148
#       I-PRODUCT-AWARD     0.0000    0.0000    0.0000       366
#         I-PRODUCT-COM     0.2776    0.3077    0.2918       221
#       I-PRODUCT-LEGAL     0.9357    0.1499    0.2584       874
#            I-QUANTITY     0.0739    0.3092    0.1193       207
#        I-QUANTITY-AGE     0.9612    0.8677    0.9121       257
#        I-QUANTITY-CUR     0.9175    0.8607    0.8882       840
#        I-QUANTITY-DIM     0.8750    0.3043    0.4516       184
#        I-QUANTITY-NUM     0.7051    0.5500    0.6180       100
#        I-QUANTITY-ORD     0.6015    0.3980    0.4790       201
#        I-QUANTITY-PER     0.9331    0.8165    0.8709       376
#        I-QUANTITY-TEM     0.7500    0.8750    0.8077        24
#               I-SKILL     0.0000    0.0000    0.0000         4
#                 I-URL     1.0000    1.0000    1.0000         4
#
#             micro avg     0.6472    0.6001    0.6227     38885
#             macro avg     0.5236    0.4179    0.4325     38885
#          weighted avg     0.6818    0.6001    0.6190     38885
#
#
# Predictions have been saved to:
# 1. test_predictions.conll - CONLL format
# 2. test_predictions_detailed.txt - Detailed analysis

# %%
print(model.config)
# Out:
# T5Config {
#   "_name_or_path": "VietAI/vit5-base",
#   "architectures": [
#     "T5ForTokenClassification"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "id2label": {
#     "0": "B-ADDRESS",
#     "1": "B-DATETIME",
#     "2": "B-DATETIME-DATE",
#     "3": "B-DATETIME-DATERANGE",
#     "4": "B-DATETIME-DURATION",
#     "5": "B-DATETIME-SET",
#     "6": "B-DATETIME-TIME",
#     "7": "B-DATETIME-TIMERANGE",
#     "8": "B-EMAIL",
#     "9": "B-EVENT",
#     "10": "B-EVENT-CUL",
#     "11": "B-EVENT-GAMESHOW",
#     "12": "B-EVENT-NATURAL",
#     "13": "B-EVENT-SPORT",
#     "14": "B-IP",
#     "15": "B-LOCATION",
#     "16": "B-LOCATION-GEO",
#     "17": "B-LOCATION-GPE",
#     "18": "B-LOCATION-STRUC",
#     "19": "B-MISCELLANEOUS",
#     "20": "B-ORGANIZATION",
#     "21": "B-ORGANIZATION-MED",
#     "22": "B-ORGANIZATION-SPORTS",
#     "23": "B-ORGANIZATION-STOCK",
#     "24": "B-PERSON",
#     "25": "B-PERSONTYPE",
#     "26": "B-PHONENUMBER",
#     "27": "B-PRODUCT",
#     "28": "B-PRODUCT-AWARD",
#     "29": "B-PRODUCT-COM",
#     "30": "B-PRODUCT-LEGAL",
#     "31": "B-QUANTITY",
#     "32": "B-QUANTITY-AGE",
#     "33": "B-QUANTITY-CUR",
#     "34": "B-QUANTITY-DIM",
#     "35": "B-QUANTITY-NUM",
#     "36": "B-QUANTITY-ORD",
#     "37": "B-QUANTITY-PER",
#     "38": "B-QUANTITY-TEM",
#     "39": "B-SKILL",
#     "40": "B-URL",
#     "41": "I-ADDRESS",
#     "42": "I-DATETIME",
#     "43": "I-DATETIME-DATE",
#     "44": "I-DATETIME-DATERANGE",
#     "45": "I-DATETIME-DURATION",
#     "46": "I-DATETIME-SET",
#     "47": "I-DATETIME-TIME",
#     "48": "I-DATETIME-TIMERANGE",
#     "49": "I-EMAIL",
#     "50": "I-EVENT",
#     "51": "I-EVENT-CUL",
#     "52": "I-EVENT-GAMESHOW",
#     "53": "I-EVENT-NATURAL",
#     "54": "I-EVENT-SPORT",
#     "55": "I-IP",
#     "56": "I-LOCATION",
#     "57": "I-LOCATION-GEO",
#     "58": "I-LOCATION-GPE",
#     "59": "I-LOCATION-STRUC",
#     "60": "I-MISCELLANEOUS",
#     "61": "I-ORGANIZATION",
#     "62": "I-ORGANIZATION-MED",
#     "63": "I-ORGANIZATION-SPORTS",
#     "64": "I-ORGANIZATION-STOCK",
#     "65": "I-PERSON",
#     "66": "I-PERSONTYPE",
#     "67": "I-PHONENUMBER",
#     "68": "I-PRODUCT",
#     "69": "I-PRODUCT-AWARD",
#     "70": "I-PRODUCT-COM",
#     "71": "I-PRODUCT-LEGAL",
#     "72": "I-QUANTITY",
#     "73": "I-QUANTITY-AGE",
#     "74": "I-QUANTITY-CUR",
#     "75": "I-QUANTITY-DIM",
#     "76": "I-QUANTITY-NUM",
#     "77": "I-QUANTITY-ORD",
#     "78": "I-QUANTITY-PER",
#     "79": "I-QUANTITY-TEM",
#     "80": "I-SKILL",
#     "81": "I-URL",
#     "82": "O"
#   },
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "label2id": {
#     "B-ADDRESS": 0,
#     "B-DATETIME": 1,
#     "B-DATETIME-DATE": 2,
#     "B-DATETIME-DATERANGE": 3,
#     "B-DATETIME-DURATION": 4,
#     "B-DATETIME-SET": 5,
#     "B-DATETIME-TIME": 6,
#     "B-DATETIME-TIMERANGE": 7,
#     "B-EMAIL": 8,
#     "B-EVENT": 9,
#     "B-EVENT-CUL": 10,
#     "B-EVENT-GAMESHOW": 11,
#     "B-EVENT-NATURAL": 12,
#     "B-EVENT-SPORT": 13,
#     "B-IP": 14,
#     "B-LOCATION": 15,
#     "B-LOCATION-GEO": 16,
#     "B-LOCATION-GPE": 17,
#     "B-LOCATION-STRUC": 18,
#     "B-MISCELLANEOUS": 19,
#     "B-ORGANIZATION": 20,
#     "B-ORGANIZATION-MED": 21,
#     "B-ORGANIZATION-SPORTS": 22,
#     "B-ORGANIZATION-STOCK": 23,
#     "B-PERSON": 24,
#     "B-PERSONTYPE": 25,
#     "B-PHONENUMBER": 26,
#     "B-PRODUCT": 27,
#     "B-PRODUCT-AWARD": 28,
#     "B-PRODUCT-COM": 29,
#     "B-PRODUCT-LEGAL": 30,
#     "B-QUANTITY": 31,
#     "B-QUANTITY-AGE": 32,
#     "B-QUANTITY-CUR": 33,
#     "B-QUANTITY-DIM": 34,
#     "B-QUANTITY-NUM": 35,
#     "B-QUANTITY-ORD": 36,
#     "B-QUANTITY-PER": 37,
#     "B-QUANTITY-TEM": 38,
#     "B-SKILL": 39,
#     "B-URL": 40,
#     "I-ADDRESS": 41,
#     "I-DATETIME": 42,
#     "I-DATETIME-DATE": 43,
#     "I-DATETIME-DATERANGE": 44,
#     "I-DATETIME-DURATION": 45,
#     "I-DATETIME-SET": 46,
#     "I-DATETIME-TIME": 47,
#     "I-DATETIME-TIMERANGE": 48,
#     "I-EMAIL": 49,
#     "I-EVENT": 50,
#     "I-EVENT-CUL": 51,
#     "I-EVENT-GAMESHOW": 52,
#     "I-EVENT-NATURAL": 53,
#     "I-EVENT-SPORT": 54,
#     "I-IP": 55,
#     "I-LOCATION": 56,
#     "I-LOCATION-GEO": 57,
#     "I-LOCATION-GPE": 58,
#     "I-LOCATION-STRUC": 59,
#     "I-MISCELLANEOUS": 60,
#     "I-ORGANIZATION": 61,
#     "I-ORGANIZATION-MED": 62,
#     "I-ORGANIZATION-SPORTS": 63,
#     "I-ORGANIZATION-STOCK": 64,
#     "I-PERSON": 65,
#     "I-PERSONTYPE": 66,
#     "I-PHONENUMBER": 67,
#     "I-PRODUCT": 68,
#     "I-PRODUCT-AWARD": 69,
#     "I-PRODUCT-COM": 70,
#     "I-PRODUCT-LEGAL": 71,
#     "I-QUANTITY": 72,
#     "I-QUANTITY-AGE": 73,
#     "I-QUANTITY-CUR": 74,
#     "I-QUANTITY-DIM": 75,
#     "I-QUANTITY-NUM": 76,
#     "I-QUANTITY-ORD": 77,
#     "I-QUANTITY-PER": 78,
#     "I-QUANTITY-TEM": 79,
#     "I-SKILL": 80,
#     "I-URL": 81,
#     "O": 82
#   },
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "torch_dtype": "float32",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 36096
# }

# %%
def predict_ner(text):
    # Ensure the model is on the correct device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Tokenize input and move to the same device
    inputs = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        max_length=256
    ).to(device)

    # Get predictions
    outputs = model(**inputs)
    predictions = torch.argmax(outputs.logits, dim=2)

    # Convert predictions to labels
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])
    word_ids = inputs.word_ids()

    results = []
    current_word = ""
    current_label = None

    for token, pred_idx, word_idx in zip(tokens, predictions[0].cpu(), word_ids):
        if word_idx is None:
            continue

        if word_idx != current_label:
            if current_word:
                results.append((current_word.strip(), id2label[current_label]))
            current_word = token.replace('▁', '')
            current_label = pred_idx.item()
        else:
            current_word += token.replace('▁', '')

    if current_word:  # Add the last word
        results.append((current_word.strip(), id2label[current_label]))

    return results

# Test prediction
def test_prediction():
    test_text = "Xem Chung kết Sao Mai : Thí sinh hát 'hit' của danh ca Whitney Houston"
    predictions = predict_ner(test_text)
    print("\nTest Prediction:")
    print("Input:", test_text)
    print("\nPredictions:")
    for token, label in predictions:
        print(f"{token}: {label}")

# Run test prediction after training
test_prediction()
